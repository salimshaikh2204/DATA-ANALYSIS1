# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("Diwali_Sales_Data.csv",encoding='unicode_escape')
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.drop(['Status','unnamed1'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
df['Amount']=df['Amount'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  int32
# dtypes: int32(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
df['Amount'].dtypes
# Out:
# dtype('int32')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df['Gender'].value_counts()
# Out:
# Gender
# F    7832
# M    3407
# Name: count, dtype: int64

# %%
df.Gender.value_counts().to_frame()
# Out:
#         count
# Gender
# F        7832
# M        3407

# %%
ax=sns.countplot(x='Gender',data=df)
for lables in ax.containers:
    ax.bar_label(lables)

# %%
gender_sales=df.groupby('Gender')['Amount'].sum().reset_index().sort_values(by='Amount',ascending=False)

# %%
gender_sales
# Out:
#   Gender    Amount
# 0      F  74335853
# 1      M  31913276

# %%
sns.barplot(x='Gender',y='Amount',data=gender_sales)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
age_group=df.groupby(['Age Group'])['Gender'].count().reset_index()

# %%
age_group
# Out:
#   Age Group  Gender
# 0      0-17     296
# 1     18-25    1879
# 2     26-35    4541
# 3     36-45    2283
# 4     46-50     983
# 5     51-55     830
# 6       55+     427

# %%
df[['Age Group','Gender']].value_counts().to_frame().sort_values(by='Age Group',ascending=False)
# Out:
#                   count
# Age Group Gender
# 55+       F         272
#           M         155
# 51-55     F         553
#           M         277
# 46-50     F         693
#           M         290
# 36-45     F        1578
#           M         705
# 26-35     F        3269
#           M        1272
# 18-25     F        1305
#           M         574
# 0-17      F         162
#           M         134

# %%
ax = sns.countplot(data=df,x='Age Group')

# %%
ax = sns.countplot(data=df,x='Age Group', hue='Gender')

for l in ax.containers:
    ax.bar_label(l)

# %%
Total_sales_by_age = df.groupby('Age Group')['Amount'].sum().reset_index().sort_values(by='Amount',ascending=False)
Total_sales_by_age
# Out:
#   Age Group    Amount
# 2     26-35  42613442
# 3     36-45  22144994
# 1     18-25  17240732
# 4     46-50   9207844
# 5     51-55   8261477
# 6       55+   4080987
# 0      0-17   2699653

# %%
ax = sns.barplot(x='Age Group',y='Amount',data=Total_sales_by_age)


ax.bar_label(ax.containers[0],labels = Total_sales_by_age['Amount'])

# for l in ax.containers:
#     ax.bar_label(l)
# Out:
# [Text(0, 0, '42613442'),
#  Text(0, 0, '22144994'),
#  Text(0, 0, '17240732'),
#  Text(0, 0, '9207844'),
#  Text(0, 0, '8261477'),
#  Text(0, 0, '4080987'),
#  Text(0, 0, '2699653')]

# %%
sales_state = df.groupby(['State'])['Orders'].sum().reset_index().sort_values(by='Orders',ascending=False).head(10)
                         

sales_state
# Out:
#                State  Orders
# 14     Uttar Pradesh    4807
# 10       Maharashtra    3810
# 7          Karnataka    3240
# 2              Delhi    2740
# 9     Madhya Pradesh    2252
# 0     Andhra Pradesh    2051
# 5   Himachal Pradesh    1568
# 8             Kerala    1137
# 4            Haryana    1109
# 3            Gujarat    1066

# %%
ax = sns.barplot(x='State',y='Orders',data=sales_state)

sns.set(rc={'figure.figsize':(15.7,14.27)})

ax.bar_label(ax.containers[0],labels=sales_state['Orders'])
# Out:
# [Text(0, 0, '4807'),
#  Text(0, 0, '3810'),
#  Text(0, 0, '3240'),
#  Text(0, 0, '2740'),
#  Text(0, 0, '2252'),
#  Text(0, 0, '2051'),
#  Text(0, 0, '1568'),
#  Text(0, 0, '1137'),
#  Text(0, 0, '1109'),
#  Text(0, 0, '1066')]

# %%
sales_amount_state = df.groupby(['State'])['Amount'].sum().reset_index().sort_values(by='Amount',ascending=False).head(10)

sales_amount_state
# Out:
#                State    Amount
# 14     Uttar Pradesh  19374968
# 10       Maharashtra  14427543
# 7          Karnataka  13523540
# 2              Delhi  11603818
# 9     Madhya Pradesh   8101142
# 0     Andhra Pradesh   8037146
# 5   Himachal Pradesh   4963368
# 4            Haryana   4220175
# 1              Bihar   4022757
# 3            Gujarat   3946082

# %%
ax = sns.barplot(x='State',y='Amount',data=sales_amount_state)

sns.set(rc={'figure.figsize':(15.7,14.27)})

ax.bar_label(ax.containers[0],labels=sales_amount_state['Amount'])
# Out:
# [Text(0, 0, '19374968'),
#  Text(0, 0, '14427543'),
#  Text(0, 0, '13523540'),
#  Text(0, 0, '11603818'),
#  Text(0, 0, '8101142'),
#  Text(0, 0, '8037146'),
#  Text(0, 0, '4963368'),
#  Text(0, 0, '4220175'),
#  Text(0, 0, '4022757'),
#  Text(0, 0, '3946082')]

# %%
ax=sns.countplot(data=df,x='Marital_Status')

sns.set(rc={'figure.figsize':(10,6)})

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '6518'), Text(0, 0, '4721')]

# %%
#TOTAL SALES BY MARTIAL STATUS,

sales_amount_status = df.groupby(['Marital_Status','Gender'])['Amount'].sum().reset_index().sort_values(by='Amount',ascending=False).head(10)

sales_amount_status

ax = sns.barplot(x='Marital_Status',y='Amount',data=sales_amount_status,hue='Gender')

sns.set(rc={'figure.figsize':(6,6)})

#ax.bar_label(ax.containers[0],labels=sales_amount_state['Gender'])

for bars in ax.containers:
    ax.bar_label(bars)

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
sales_amount_occup = df.groupby(['Occupation'])['Amount'].sum().reset_index().sort_values(by='Amount',ascending=False)


sales_amount_occup

# ax = sns.barplot(x='Occupation',y='Amount',data=sales_amount_occup)

# sns.set(rc={'figure.figsize':(15,5)})

# ax.bar_label(ax.containers[0],labels=sales_amount_occup['Amount'])

# for bars in ax.containers:
#     ax.bar_label(bars)
# Out:
#          Occupation    Amount
# 10        IT Sector  14755079
# 8        Healthcare  13034586
# 2          Aviation  12602298
# 3           Banking  10770610
# 7              Govt   8517212
# 9       Hospitality   6376405
# 12            Media   6295832
# 1        Automobile   5368596
# 4          Chemical   5297436
# 11           Lawyer   4981665
# 13           Retail   4783170
# 6   Food Processing   4070670
# 5      Construction   3597511
# 14          Textile   3204972
# 0       Agriculture   2593087

# %%
ax = sns.barplot(x='Occupation',y='Amount',data=sales_amount_occup)

sns.set(rc={'figure.figsize':(20,5)})

ax.bar_label(ax.containers[0],labels=sales_amount_occup['Amount'])
# Out:
# [Text(0, 0, '14755079'),
#  Text(0, 0, '13034586'),
#  Text(0, 0, '12602298'),
#  Text(0, 0, '10770610'),
#  Text(0, 0, '8517212'),
#  Text(0, 0, '6376405'),
#  Text(0, 0, '6295832'),
#  Text(0, 0, '5368596'),
#  Text(0, 0, '5297436'),
#  Text(0, 0, '4981665'),
#  Text(0, 0, '4783170'),
#  Text(0, 0, '4070670'),
#  Text(0, 0, '3597511'),
#  Text(0, 0, '3204972'),
#  Text(0, 0, '2593087')]

# %%
sales_product_category = df.groupby(['Product_Category'])['Amount'].sum().reset_index().sort_values(by='Amount',ascending=False).head(10)


sales_product_category

ax = sns.barplot(x='Product_Category',y='Amount',data=sales_product_category)

sns.set(rc={'figure.figsize':(15,5)})

ax.bar_label(ax.containers[0],labels=sales_product_category['Amount'])
# Out:
# [Text(0, 0, '33933883'),
#  Text(0, 0, '16495019'),
#  Text(0, 0, '15643846'),
#  Text(0, 0, '15575209'),
#  Text(0, 0, '5440051'),
#  Text(0, 0, '4331694'),
#  Text(0, 0, '3635933'),
#  Text(0, 0, '1959484'),
#  Text(0, 0, '1958609'),
#  Text(0, 0, '1676051')]

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
sales_product_id = df.groupby(['Product_ID'])['Amount'].sum().reset_index().sort_values(by='Amount',ascending=False).head(10)


sales_product_id

ax = sns.barplot(x='Product_ID',y='Amount',data=sales_product_id)

sns.set(rc={'figure.figsize':(15,5)})

ax.bar_label(ax.containers[0],labels=sales_product_id['Amount'])
# Out:
# [Text(0, 0, '540136'),
#  Text(0, 0, '424833'),
#  Text(0, 0, '401816'),
#  Text(0, 0, '341020'),
#  Text(0, 0, '338571'),
#  Text(0, 0, '322363'),
#  Text(0, 0, '307040'),
#  Text(0, 0, '294548'),
#  Text(0, 0, '290661'),
#  Text(0, 0, '283309')]

# %%
sales_top_product_id = df.groupby(['Product_ID'])['Amount'].sum().nlargest(10).reset_index()


sales_top_product_id 

ax = sns.barplot(x='Product_ID',y='Amount',data=sales_top_product_id )

sns.set(rc={'figure.figsize':(15,5)})

ax.bar_label(ax.containers[0],labels=sales_top_product_id ['Amount'])
# Out:
# [Text(0, 0, '540136'),
#  Text(0, 0, '424833'),
#  Text(0, 0, '401816'),
#  Text(0, 0, '341020'),
#  Text(0, 0, '338571'),
#  Text(0, 0, '322363'),
#  Text(0, 0, '307040'),
#  Text(0, 0, '294548'),
#  Text(0, 0, '290661'),
#  Text(0, 0, '283309')]
